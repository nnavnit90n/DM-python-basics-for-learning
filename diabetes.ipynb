# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d=pd.read_csv('C:\\Users\\Admin\\Desktop\\dataset\\diabetes.csv')
print(d)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x=d['Age'][0:6]
y=d['BMI'][0:6]
print(x,y)
# Out:
# 0    50
# 1    31
# 2    32
# 3    21
# 4    33
# 5    30
# Name: Age, dtype: int64 0    33.6
# 1    26.6
# 2    23.3
# 3    28.1
# 4    43.1
# 5    25.6
# Name: BMI, dtype: float64

# %%
plt.scatter(x,y,color='r',s=100,marker='o')
plt.show()

# %%
d1=d.groupby('Age')[['BMI']].mean()
print(d1)
# Out:
#            BMI
# Age
# 21   27.817460
# 22   29.509722
# 23   31.502632
# 24   32.569565
# 25   31.943750
# 26   34.915152
# 27   31.950000
# 28   33.642857
# 29   33.541379
# 30   30.033333
# 31   34.016667
# 32   32.318750
# 33   32.335294
# 34   31.164286
# 35   33.780000
# 36   31.718750
# 37   32.078947
# 38   35.568750
# 39   31.983333
# 40   33.538462
# 41   35.259091
# 42   34.983333
# 43   36.892308
# 44   34.162500
# 45   34.960000
# 46   34.523077
# 47   34.566667
# 48   29.980000
# 49   32.020000
# 50   31.225000
# 51   33.975000
# 52   33.475000
# 53   30.500000
# 54   30.800000
# 55   27.025000
# 56   31.700000
# 57   29.700000
# 58   32.428571
# 59   26.966667
# 60   28.740000
# 61   30.000000
# 62   28.950000
# 63   30.775000
# 64   25.000000
# 65   31.600000
# 66   30.375000
# 67   28.766667
# 68   35.600000
# 69   13.400000
# 70   32.500000
# 72   19.600000
# 81   25.900000

# %% [markdown]
#  # if we need to select the range of row , using ther labels we can use method loc:
#  df_sub.loc[10:20['rank','sex','salary']]

# %% [markdown]
# # using there position we use method iloc:
#
# df_sub.iloc[10:20[0,3,4,5]]

# %%
d1.iloc[0]
# Out:
# BMI    27.81746
# Name: 21, dtype: float64

# %%
d1.iloc[-1]
# Out:
# BMI    25.9
# Name: 81, dtype: float64

# %%
d1.iloc[:,0]
# Out:
# Age
# 21    27.817460
# 22    29.509722
# 23    31.502632
# 24    32.569565
# 25    31.943750
# 26    34.915152
# 27    31.950000
# 28    33.642857
# 29    33.541379
# 30    30.033333
# 31    34.016667
# 32    32.318750
# 33    32.335294
# 34    31.164286
# 35    33.780000
# 36    31.718750
# 37    32.078947
# 38    35.568750
# 39    31.983333
# 40    33.538462
# 41    35.259091
# 42    34.983333
# 43    36.892308
# 44    34.162500
# 45    34.960000
# 46    34.523077
# 47    34.566667
# 48    29.980000
# 49    32.020000
# 50    31.225000
# 51    33.975000
# 52    33.475000
# 53    30.500000
# 54    30.800000
# 55    27.025000
# 56    31.700000
# 57    29.700000
# 58    32.428571
# 59    26.966667
# 60    28.740000
# 61    30.000000
# 62    28.950000
# 63    30.775000
# 64    25.000000
# 65    31.600000
# 66    30.375000
# 67    28.766667
# 68    35.600000
# 69    13.400000
# 70    32.500000
# 72    19.600000
# 81    25.900000
# Name: BMI, dtype: float64

# %%
d1.iloc[:,-1]
# Out:
# Age
# 21    27.817460
# 22    29.509722
# 23    31.502632
# 24    32.569565
# 25    31.943750
# 26    34.915152
# 27    31.950000
# 28    33.642857
# 29    33.541379
# 30    30.033333
# 31    34.016667
# 32    32.318750
# 33    32.335294
# 34    31.164286
# 35    33.780000
# 36    31.718750
# 37    32.078947
# 38    35.568750
# 39    31.983333
# 40    33.538462
# 41    35.259091
# 42    34.983333
# 43    36.892308
# 44    34.162500
# 45    34.960000
# 46    34.523077
# 47    34.566667
# 48    29.980000
# 49    32.020000
# 50    31.225000
# 51    33.975000
# 52    33.475000
# 53    30.500000
# 54    30.800000
# 55    27.025000
# 56    31.700000
# 57    29.700000
# 58    32.428571
# 59    26.966667
# 60    28.740000
# 61    30.000000
# 62    28.950000
# 63    30.775000
# 64    25.000000
# 65    31.600000
# 66    30.375000
# 67    28.766667
# 68    35.600000
# 69    13.400000
# 70    32.500000
# 72    19.600000
# 81    25.900000
# Name: BMI, dtype: float64

# %%
d1.iloc[0:7]
# Out:
#            BMI
# Age
# 21   27.817460
# 22   29.509722
# 23   31.502632
# 24   32.569565
# 25   31.943750
# 26   34.915152
# 27   31.950000

# %%
d1.iloc[:,0:2] # first two column
# Out:
#            BMI
# Age
# 21   27.817460
# 22   29.509722
# 23   31.502632
# 24   32.569565
# 25   31.943750
# 26   34.915152
# 27   31.950000
# 28   33.642857
# 29   33.541379
# 30   30.033333
# 31   34.016667
# 32   32.318750
# 33   32.335294
# 34   31.164286
# 35   33.780000
# 36   31.718750
# 37   32.078947
# 38   35.568750
# 39   31.983333
# 40   33.538462
# 41   35.259091
# 42   34.983333
# 43   36.892308
# 44   34.162500
# 45   34.960000
# 46   34.523077
# 47   34.566667
# 48   29.980000
# 49   32.020000
# 50   31.225000
# 51   33.975000
# 52   33.475000
# 53   30.500000
# 54   30.800000
# 55   27.025000
# 56   31.700000
# 57   29.700000
# 58   32.428571
# 59   26.966667
# 60   28.740000
# 61   30.000000
# 62   28.950000
# 63   30.775000
# 64   25.000000
# 65   31.600000
# 66   30.375000
# 67   28.766667
# 68   35.600000
# 69   13.400000
# 70   32.500000
# 72   19.600000
# 81   25.900000

# %%
d1.iloc[1:3,0:2] # second through third row and first 2 columns
# Out:
#            BMI
# Age
# 22   29.509722
# 23   31.502632

# %% [markdown]
# # sorting the data acoording to the services
#
# df_sorted=df.sort_values(by='services')
# df_sorted_head(

# %%
d=d.sort_values(by='BMI')
d.head(50)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 145            0      102             75             23        0   0.0
# 81             2       74              0              0        0   0.0
# 426            0       94              0              0        0   0.0
# 9              8      125             96              0        0   0.0
# 60             2       84              0              0        0   0.0
# 494            3       80              0              0        0   0.0
# 371            0      118             64             23       89   0.0
# 49             7      105              0              0        0   0.0
# 522            6      114              0              0        0   0.0
# 706           10      115              0              0        0   0.0
# 684            5      136             82              0        0   0.0
# 418            1       83             68              0        0  18.2
# ...

# %% [markdown]
# df_sorted=df.sort_values(by=['services','salaries'],ascending=[True,False])
# df_sorted_head()

# %%
d=d.sort_values(by=['BMI','Glucose','Age'],ascending=[True,False,False])
d.head(50)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 684            5      136             82              0        0   0.0
# 9              8      125             96              0        0   0.0
# 371            0      118             64             23       89   0.0
# 706           10      115              0              0        0   0.0
# 522            6      114              0              0        0   0.0
# 49             7      105              0              0        0   0.0
# 145            0      102             75             23        0   0.0
# 426            0       94              0              0        0   0.0
# 60             2       84              0              0        0   0.0
# 494            3       80              0              0        0   0.0
# 81             2       74              0              0        0   0.0
# 438            1       97             70             15        0  18.2
# ...

# %%
d.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 684        False    False          False          False    False  False
# 9          False    False          False          False    False  False
# 371        False    False          False          False    False  False
# 706        False    False          False          False    False  False
# 522        False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 120        False    False          False          False    False  False
# 125        False    False          False          False    False  False
# 673        False    False          False          False    False  False
# 445        False    False          False          False    False  False
# 177        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 684                     False  False    False
# ...

# %% [markdown]
# # when summing the data ,missing the values will e treated as zero
# # if all vlues are missing the sum will be qual to nan
# # cumsum() and cumprod() methods ignore missing values but preserve them in the reulting arrays
# # missing values is groupby method are excluded (just like R)
# # Many descriptive stataics methods have skipna option to control if the missing data  should be excluded. This value is set  True by default(unlike R)

# %% [markdown]
# # Agrregation:- computing a summary statics about each group
# . compute groups sums or means
# . compute group sizes/counts
# # commmon aggregartion function:
# . min,max
# .count,sum,prod
# .mean,median,mode,mad
# .std,var
